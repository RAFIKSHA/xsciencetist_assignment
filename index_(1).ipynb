# %% [markdown]
# <a href="https://colab.research.google.com/github/RAFIKSHA/XST_Transformation_CSV_to_DB/blob/main/index_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# importing packages import pandas as pd

import pandas as pd

#Importing Github Repository
# !git clone https://github.com/RAFIKSHA/XST_Transformation_CSV_to_DB.git
# Out:
# fatal: destination path 'XST_Transformation_CSV_to_DB' already exists and is not an empty directory.

# %% [markdown]
# # New Section

# %%
# Read data from CSV file
dataset = pd.read_csv("/content/XST_Transformation_CSV_to_DB/india-state-wise-data-analysis.csv")

# %%
from tables.table import Column
# Preprocess data
def preprocess_data(df):
    # Split combined data in the 'state & district' column
    #df[['district_code','state_name', 'district_name']] = df['State & District'].str.split(",", expand=True)
    lst = df['State & District'].str.split(",", expand=True)
    #print("List: ", lst)
    df.drop(columns=['State & District'], inplace=True)

    df.insert(0,column = "District_Code", value= lst[0].str.replace("district_code:",""))
    df.insert(1,column = "State_Name", value= lst[1].str.replace("state_name:",""))
    df.insert(2,column = "District_Name", value= lst[2].str.replace("district_name:",""))

    return df

# Preprocess the data
preprocessed_set= preprocess_data(dataset.copy())

# Displaying preprocessed data
print("Preprocessed Data is:")
preprocessed_set.head()
# Out:
# Preprocessed Data is:
#   District_Code          State_Name District_Name  Population    Male  Female  \
# 0             1   JAMMU AND KASHMIR       Kupwara      870354  474190  396164
# 1             2   JAMMU AND KASHMIR        Badgam      753745  398041  355704
# 2             3   JAMMU AND KASHMIR   Leh(Ladakh)      133487   78971   54516
# 3             4   JAMMU AND KASHMIR        Kargil      140802   77785   63017
# 4             5   JAMMU AND KASHMIR         Punch      476835  251899  224936
#
#    Literate  Male_Literate  Female_Literate    SC  ...  Secondary_Education  \
# 0    439654         282823           156831  1048  ...                74948
# 1    335649         207741           127908   368  ...                66459
# 2     93770          62834            30936   488  ...                16265
# 3     86236          56301            29935    18  ...                16938
# 4    261724         163333            98391   556  ...                46062
#
# ...

# %% [markdown]
# Creating Seperate Tables

# %%
#District info Table:

distrinct_infoSet = preprocessed_set[["District_Code", "State_Name", "District_Name"]]
distrinct_infoSet.head()

#Population info Table
population_infoSet = preprocessed_set[["District_Code", "Population", "Male", "Female"]]
population_infoSet.head()

#Population info Table
population_infoSet = preprocessed_set[["District_Code", "Population", "Male", "Female"]]
population_infoSet.head()
# Out:
#   District_Code  Population    Male  Female
# 0             1      870354  474190  396164
# 1             2      753745  398041  355704
# 2             3      133487   78971   54516
# 3             4      140802   77785   63017
# 4             5      476835  251899  224936

# %%
import mysql.connector

mydb=mysql.connector.connect(
    host='localhost',
    user='root',
    password='root',
    database='xst'
)
print(mydb)
mycursor=mydb.cursor()
mycursor.execute("create database xst3")
print('database created')
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/mysql/connector/connection_cext.py in _open_connection(self)
#     301         try:
# --> 302             self._cmysql.connect(**cnx_kwargs)
#     303             self._cmysql.converter_str_fallback = self._converter_str_fallback
#
# MySQLInterfaceError: Can't connect to MySQL server on 'localhost:3306' (99)
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-31-a11a6166a4af> in <cell line: 3>()
#       1 import mysql.connector
#       2
# ----> 3 mydb=mysql.connector.connect(
#       4     host='localhost',
#       5     user='root',
#
# /usr/local/lib/python3.10/dist-packages/mysql/connector/pooling.py in connect(*args, **kwargs)
#     291
# ...
